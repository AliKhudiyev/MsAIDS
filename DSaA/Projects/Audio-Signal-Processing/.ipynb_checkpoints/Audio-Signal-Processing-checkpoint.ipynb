# %%
import numpy as np
from matplotlib import pyplot as plt
# import wave
from scipy.io import wavfile
from scipy import signal
import os
import simpleaudio as sa
import sounddevice as sd
import copy

# %% [markdown]
# # Part 1: Extraction and visualization of hearbeat signals

# %%
files = os.listdir('data')
fig, axs = plt.subplots(3, 4, figsize=(6*4, 6*3))
for i, file in enumerate(files):
    sample_rate, signal = wavfile.read('data/'+file)
    axs[i//4, i%4].plot(range(len(signal)), signal);

# %%
def play(file, plot=False):
    sample_rate, signal = wavfile.read('data/'+file)
    if plot:
        plt.plot(range(len(signal)), signal);
    sd.play(signal, sample_rate)

# %%
play(files[0], plot=True)
# 0 - normal
# 1 - normal/murmur
# 2 - extra ?
# 3 - 
# 4 - artifact
# 5 -
# 6 - extra ?
# 7 - other
# 8 - other
# 9 - normal
# 10 - other
# 11 -

# %%
def magic(sound_file, threshold=0, sample_rate=None, plot=False, play=False):
    sample_rate, sound = wavfile.read('data/'+sound_file)
    sound_copy = copy.deepcopy(sound)
#     for i in range(len(sound)-threshold):
#         total = 0
#         amp_list = []
#         for j in range(threshold):
#             total += sound[i+j]
#             amp_list.append(sound[i+j])
#         sound_copy[i] = int(total / threshold)
#         sound_copy[i] = np.median(amp_list)
        
#         if np.abs(sound[i]) > threshold:
#             sign = 0
    
    if plot:
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))
        axs[0].set_title('Original')
        axs[1].set_title('After magic')
        
        axs[0].plot(range(len(sound_copy)), sound)
        axs[1].plot(range(len(sound_copy)), sound_copy)
    if play and sample_rate is not None:
        sd.play(sound_copy, sample_rate)
    return sound_copy

# %%
signal_copy = magic(files[0], threshold=150, sample_rate=sample_rate, plot=True, play=True)
# signal_copy = magic(signal, threshold=500, sample_rate=sample_rate, plot=True, play=True)

# %%
b, a = signal.butter(3, 0.001, btype='lowpass', analog=False)
print(a, b)
print(signal_copy[:10])
low_passed = signal.filtfilt(b, a, signal_copy)
# magic(low_passed, plot=True)
plt.plot(range(len(low_passed)), low_passed);
sd.play(low_passed, sample_rate)
# Out:
# [ 1.         -2.99371682  2.98745336 -0.99373651] [3.86363708e-09 1.15909112e-08 1.15909112e-08 3.86363708e-09]
# [285 270 275 196 150  83  72  -3 -47 -99]
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# <ipython-input-133-99998183f965> in <module>
#       5 # magic(low_passed, plot=True)
#       6 plt.plot(range(len(low_passed)), low_passed);
# ----> 7 sd.play(low_passed, sample_rate)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sounddevice.py in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     177         ctx.callback_exit()
#     178
# --> 179     ctx.start_stream(OutputStream, samplerate, ctx.output_channels,
#     180                      ctx.output_dtype, callback, blocking,
#     181                      prime_output_buffers_using_stream_callback=False,
#
# ...

# %% [markdown]
# ---
#
# # Part 2: Classfication of heartbeat signals

# %%
categories = ['normal', 'murmur', 'extra', 'artifact', 'extrasystole', 'other']

def classify(sounds):
    pass
