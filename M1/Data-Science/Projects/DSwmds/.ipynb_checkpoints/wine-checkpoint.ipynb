# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report

# %%
wine = pd.read_csv('datasets/wine.csv', header=None, names=['type', 'alcohol', 'malic_acid', 'ash', 'ash_alcalinity', 'magnesium', 'total_phenols', 'flavanoids', 'nonflav_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'OD280/OD315', 'proline'])
wine
# Out:
#      type  alcohol  malic_acid   ash  ash_alcalinity  magnesium  \
# 0       1    14.23        1.71  2.43            15.6        127
# 1       1    13.20        1.78  2.14            11.2        100
# 2       1    13.16        2.36  2.67            18.6        101
# 3       1    14.37        1.95  2.50            16.8        113
# 4       1    13.24        2.59  2.87            21.0        118
# ..    ...      ...         ...   ...             ...        ...
# 173     3    13.71        5.65  2.45            20.5         95
# 174     3    13.40        3.91  2.48            23.0        102
# 175     3    13.27        4.28  2.26            20.0        120
# 176     3    13.17        2.59  2.37            20.0        120
# 177     3    14.13        4.10  2.74            24.5         96
#
#      total_phenols  flavanoids  nonflav_phenols  proanthocyanins  \
# 0             2.80        3.06             0.28             2.29
# ...

# %%
wine.isna().sum()
# Out:
# type               0
# alcohol            0
# malic_acid         0
# ash                0
# ash_alcalinity     0
# magnesium          0
# total_phenols      0
# flavanoids         0
# nonflav_phenols    0
# proanthocyanins    0
# color_intensity    0
# hue                0
# OD280/OD315        0
# proline            0
# dtype: int64

# %%
X = wine.drop(['type'], axis=1)
y = wine['type']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
sns.pairplot(wine[['type', 'flavanoids', 'OD280/OD315', 'proline']], hue='type');
# wine[['type', 'flavanoids']]
# plt.scatter(wine['flavanoids'], wine['OD280/OD315'], c=wine['type']);

# %%
corr_mat = wine.corr()
# sns.heatmap(corr_mat, annot=True);
wine.corr()
# Out:
#                      type   alcohol  malic_acid       ash  ash_alcalinity  \
# type             1.000000 -0.328222    0.437776 -0.049643        0.517859
# alcohol         -0.328222  1.000000    0.094397  0.211545       -0.310235
# malic_acid       0.437776  0.094397    1.000000  0.164045        0.288500
# ash             -0.049643  0.211545    0.164045  1.000000        0.443367
# ash_alcalinity   0.517859 -0.310235    0.288500  0.443367        1.000000
# magnesium       -0.209179  0.270798   -0.054575  0.286587       -0.083333
# total_phenols   -0.719163  0.289101   -0.335167  0.128980       -0.321113
# flavanoids      -0.847498  0.236815   -0.411007  0.115077       -0.351370
# nonflav_phenols  0.489109 -0.155929    0.292977  0.186230        0.361922
# proanthocyanins -0.499130  0.136698   -0.220746  0.009652       -0.197327
# color_intensity  0.265668  0.546364    0.248985  0.258887        0.018732
# hue             -0.617369 -0.071747   -0.561296 -0.074667       -0.273955
# ...

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)

y_pred = dtc.predict(X_test)
print(classification_report(y_test, y_pred, target_names=['Wine 0', 'Wine 1', 'Wine 2']))
# Out:
#               precision    recall  f1-score   support
#
#       Wine 0       0.91      0.97      0.94        31
#       Wine 1       0.86      0.86      0.86        37
#       Wine 2       0.84      0.76      0.80        21
#
#     accuracy                           0.88        89
#    macro avg       0.87      0.86      0.87        89
# weighted avg       0.87      0.88      0.87        89

# %% [markdown]
# # My model

# %%
def predict(X, X_known, y_known, n=1):
    y = list()
    for X_i in X:
        dists = [np.linalg.norm(np.subtract(np.array(X_i), np.array(X_j))) for X_j in X_known]
        norm_coef = 1

        for i in range(n):
            pass
    return y

def evaluate(y_pred, y_known, metrics=['accuracy', 'precision']):
    pass

# %%
from vpi import *

sayit()
# Out:
# working
